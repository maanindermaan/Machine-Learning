# %%
import pandas as pd
df = pd.read_csv('p2_WineQuality.csv')

# %%
# 1. Summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32485 entries, 0 to 32484
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            32485 non-null  int64
#  1   fixed acidity         32485 non-null  float64
#  2   volatile acidity      32485 non-null  float64
#  3   citric acid           32485 non-null  float64
#  4   residual sugar        32485 non-null  float64
#  5   chlorides             32485 non-null  float64
#  6   free sulfur dioxide   32485 non-null  float64
#  7   total sulfur dioxide  32485 non-null  float64
#  8   density               32485 non-null  float64
#  9   pH                    32485 non-null  float64
#  10  sulphates             32485 non-null  float64
#  11  alcohol               32485 non-null  float64
#  12  quality               32485 non-null  int64
#  13  Type                  32485 non-null  object
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
# 2. Descriptive summary 
df.describe()
# Out:
#          Unnamed: 0  fixed acidity  volatile acidity   citric acid  \
# count  32485.000000   32485.000000      32485.000000  32485.000000
# mean    3251.548376       7.214736          0.340122      0.318324
# std     1873.780954       1.308216          0.164912      0.145152
# min        0.000000       3.800000          0.080000      0.000000
# 25%     1627.000000       6.400000          0.230000      0.250000
# 50%     3249.000000       7.000000          0.290000      0.310000
# 75%     4875.000000       7.700000          0.410000      0.390000
# max     6496.000000      15.900000          1.580000      1.660000
#
#        residual sugar     chlorides  free sulfur dioxide  \
# count    32485.000000  32485.000000         32485.000000
# mean         5.438696      0.056009            30.458258
# std          4.799221      0.034503            17.608076
# min          0.600000      0.009000             1.000000
# 25%          1.800000      0.038000            17.000000
# ...

# %%
# 3. shape of dataset
df.shape
# Out:
# (32485, 14)

# %%
# 4. Listing all columns
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality', 'Type'],
#       dtype='object')

# %%
df['quality'].unique
# Out:
# <bound method Series.unique of 0        6
# 1        6
# 2        6
# 3        6
# 4        5
#         ..
# 32480    6
# 32481    5
# 32482    6
# 32483    7
# 32484    4
# Name: quality, Length: 32485, dtype: int64>

# %%
df['quality'].value_counts()
# Out:
# 6    14117
# 5    10755
# 7     5371
# 4     1144
# 8      941
# 3      133
# 9       24
# Name: quality, dtype: int64

# %%
# so it is imbalanced data 
# 5. finding missing values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Type                    0
# dtype: int64

# %%
# 6. checking duplicate records
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32480     True
# 32481     True
# 32482     True
# 32483     True
# 32484     True
# Length: 32485, dtype: bool

# %%
df[df.duplicated()]
# Out:
#        Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 50           2176            7.1             0.260         0.32
# 84           4735            9.6             0.380         0.42
# 230          6176            5.7             0.160         0.26
# 238           770            6.8             0.180         0.30
# 269          1954            9.5             0.590         0.44
# ...           ...            ...               ...          ...
# 32480        2838            5.0             0.255         0.22
# 32481        6414            6.6             0.360         0.52
# 32482        1126            6.3             0.200         0.24
# 32483        2924            6.2             0.200         0.33
# 32484        5462            8.1             0.280         0.46
#
#        residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 50              14.45      0.074                 29.0                 107.0
# ...

# %%
# 7. Dropping duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (6449, 14)

# %%
# 8. Correlation 
df.corr()
# Out:
#                       Unnamed: 0  fixed acidity  volatile acidity  \
# Unnamed: 0              1.000000      -0.004615          0.005052
# fixed acidity          -0.004615       1.000000          0.218663
# volatile acidity        0.005052       0.218663          1.000000
# citric acid            -0.008726       0.325288         -0.376828
# residual sugar         -0.018074      -0.111229         -0.195351
# chlorides              -0.000270       0.296920          0.376415
# free sulfur dioxide    -0.000894      -0.282322         -0.352107
# total sulfur dioxide   -0.009651      -0.329061         -0.414272
# density                -0.024515       0.458890          0.270428
# pH                     -0.008557      -0.252965          0.259900
# sulphates              -0.015464       0.300618          0.225365
# alcohol                 0.020398      -0.095779         -0.037168
# quality                 0.008636      -0.076163         -0.266444
#
# ...

# %%
# 9. Heatmap for correlation 
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
# 10. Bar plot
df.quality.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 11 Distribution of volatile acidity
sns.distplot(df['volatile acidity'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
# 12. Histplot
sns.histplot(df['volatile acidity'] , kde=True)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Count'>

# %%
for i in df.columns:
    sns.histplot(df[i] , kde=True)

# %%
# 13. categorical plot
sns.catplot(x='quality' , y = 'alcohol' , data=df , kind='box')

# %%
# 14. Scatter plot
sns.scatterplot(x='alcohol' , y='pH' , data=df , hue='quality')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='pH'>
