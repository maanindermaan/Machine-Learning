# %%
# Webscrapping -> iski help se boht sara data acquire karte ho or uske uper ml , dl , computer vision and other model apply krte ho jo aage kaam ayega

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
# i dont want that i go individually and check for each and every review so what we do is :

# %%
amazon_url = "https://www.amazon.in/s?k=" + "iphone13"

# %%
amazon_url
# Out:
# 'https://www.amazon.in/s?k=iphone13'

# %%
# ab isse kya hoga ki mera url to same hi rhega but ye jo humne concatenate kiya hai "iphone11" ye change hota rhega during deployment, ye input bhi hum le sakte hai

# %%
# automatic url open

# %%
urlclient = urlopen(amazon_url)

# %%
urlclient

# %%
amazon_page = urlclient.read()

# %%
amazon_page
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open
# ...

# %%
bs(amazon_page , 'html.parser')
# baar baar run karna padega because cursor end mein chala jaata hai
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
amazon_html = bs(amazon_page , 'html.parser')

# %%
amazon_html
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
# ab mujhe one by one click karna padega to see the reviews

# %%
# you will href while doing inspect and that is the thing from which you can click this object
# agar hum iss href wale url ko nikal le to click krke one by one hum ja sakte hai or data nikal sakte hai

# %%
"https://www.amazon.in/"+"/Apple-iPhone-13-128GB-Pink/dp/B09G9FPGTN/ref=sr_1_3?crid=MM6EDPY41OG7&keywords=iphone+13&nsdOptOutParam=true&qid=1697354777&sprefix=iphone+1%2Caps%2C333&sr=8-3"
# Out:
# 'https://www.amazon.in//Apple-iPhone-13-128GB-Pink/dp/B09G9FPGTN/ref=sr_1_3?crid=MM6EDPY41OG7&keywords=iphone+13&nsdOptOutParam=true&qid=1697354777&sprefix=iphone+1%2Caps%2C333&sr=8-3'

# %%
# agar alag alag product click krne hai toh inspect krke one by one hum href nikalke uske andar ja sakte hai.
# ab hum product wale page tak pochach parhe hai

# %%
# But how to make this automatically?

# %%
amazon_html 
# isi ke andar sab available hai
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
# we can do find() and we can find tags
bigbox = amazon_html.findAll("div" , {"class": "sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16"})

# %%
len(bigbox)
# Out:
# 16

# %%
# del bigbox[0:4]

# %%
# ab isi box ke andar hai mera link
productlink = "https://www.amazon.in" + bigbox[0].div.div.div.div.div.div.div.a['href']

# %%
# ab hum ek ek product link ko open karna shuru karenge

# %%
product_req = requests.get(productlink)

# %%
productlink
# ab hum iske section mein jayenge jha review likha hua hai or one by one extract krna shuru karenge
# Out:
# 'https://www.amazon.in/Apple-iPhone-13-256GB-Midnight/dp/B09G9BQS98'

# %%
product_html = bs(product_req.text , "html.parser")

# %%
product_html
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">Amazon.in</title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#
# if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
product_html.findAll("div" , {"id" : "dp"})
# Out:
# []

# %%
for i in bigbox:
    print("https://www.amazon.in" + i.div.div.div.div.div.div.div.a['href'])
# Out:
# https://www.amazon.in/Apple-iPhone-13-256GB-Midnight/dp/B09G9BQS98
# https://www.amazon.in/Apple-iPhone-13-512GB-Blue/dp/B09G9JJT7M
# https://www.amazon.in/Apple-iPhone-13-512GB-Starlight/dp/B09G99B791
# https://www.amazon.in/Apple-iPhone-13-512GB-Pink/dp/B09G97M122
# https://www.amazon.in/Apple-iPhone-13-512GB-Product/dp/B09G95PVDX
# https://www.amazon.in/Apple-iPhone-13-512GB-Midnight/dp/B09G984RNC
# https://www.amazon.in/Apple-iPhone-13-512-GB/dp/B09V4KHL1B
# https://www.amazon.in/Apple-iPhone-13-Mini-512GB/dp/B09G997HJP
# https://www.amazon.in/Apple-iPhone-13-128GB-Starlight/dp/B09G9D8KRQ
# https://www.amazon.in/Apple-iPhone-13-128GB-Pink/dp/B09G9FPGTN
# https://www.amazon.in/Apple-iPhone-13-128GB-Blue/dp/B09G9BL5CP
# https://www.amazon.in/Apple-iPhone-13-128GB-Midnight/dp/B09G9HD6PD
# https://www.amazon.in/Samsung-Waterfall-sAMOLED-Display-Security/dp/B0C7C28GKF
# https://www.amazon.in/Apple-iPhone-13-128GB-Green/dp/B09V4B6K53
# ...
